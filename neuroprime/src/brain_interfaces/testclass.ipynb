# %%
from phdproject.maincode.src.initbciclass import initbciclass
import time

# %%
class testclass(initbciclass):
    def init(self):
        """
        INIT Global Constants
        """
        #1.INIT Parent Class
        initbciclass.init(self)
        #2.Alter or add other functions
        
    def on_play(self, markernumerate=0):
        """
        PLAY 
        """
        ##UPDATE/RESET
        self.update_file_path() #update filename with runtrial_nr
        
        #Instructions
        self.INIT_TEXT="\n\n\n\n\nTASK 1: Estado de Repouso, 2 min!"
        
        #Stimulus
        self.STIMULUS_TEXT ="\n\n\n\n\n\n\n\n\n\n+"
        self.PROTOCOL_TYPE =  "REST"
        self.PROTOCOL_DESIGN = "normal" #normal, ABA
        self.STIM_TIME = 60*1 #s
        self.subtask='rest'+"_"+str(markernumerate)
        self.START_MARKER = "START_"+self.subtask
        self.END_MARKER = "END_"+self.subtask
        
        #START loop of data
        self.start_time = time.time() #start time
        self.on_loop()
        self.end_time = time.time()  #end time
        self.elapsed_time =self.end_time - self.start_time

# %%
#1.Start Class
test = testclass()
#2.SAVE information
test.SAVE = False
test.FOLDER_DATA = "/testdata"
test.GROUP = 'TEST'
test.SUBJECT_NR = 1
test.SESSION_NR = 1
#INIT Methods - Saving, Acquisition and Presentation
test.on_init()
#start experiment
test.RUNTRIAL_NR = 1 #1st trial
test.on_play(markernumerate=test.RUNTRIAL_NR)
test.RUNTRIAL_NR = test.RUNTRIAL_NR+1 #2nd trial
test.on_play(markernumerate=test.RUNTRIAL_NR)

#quit
test.on_quit()
# Out:
# INFO:testclass:***init***
# INFO:testclass:
# >> ***on_init***
# INFO:testclass:***init_io***
# INFO:testclass:CURRENT FILE PATH: None
# INFO:testclass:***init_io***ELAPSED TIME: 0.00475311279297
# INFO:testclass:***init_presentation***
# WARNING:testclass:
# >> Pyff Waiting for connection...
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> Streams : [u'PyffMarkerStream', u'BrainVision RDA']
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> GREAT - Only 1 PyffMarkerStream stream!
# INFO:testclass:***set_pyff_vars***
# INFO:testclass:***set_pyff_vars***ELAPSED TIME: 0.000125885009766
# INFO:testclass:***init_presentation***ELAPSED TIME: 8.01861786842
# INFO:testclass:***init_acquisition***
# WARNING:libmushu.driver.labstreaminglayer:
# >> *****WAITING EEG STREAM: ******
# WARNING:libmushu.driver.labstreaminglayer:
# >> Waiting LSL EEG stream...
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> Streams : [u'PyffMarkerStream', u'BrainVision RDA']
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> GREAT - Only 1 BrainVision RDA stream!
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> Testing INLET PERFORMANCE....
# INFO:phdproject.maincode.src.functions.myfunctions:
# >> Sample Chunk length = 50
# INFO:phdproject.maincode.src.functions.myfunctions:
# >> LSL timestamp = 85534.2209347
# INFO:phdproject.maincode.src.functions.myfunctions:
# >> Server timestamp = 85534.218306
# INFO:phdproject.maincode.src.functions.myfunctions:
# >> Offset = 0.003
# INFO:phdproject.maincode.src.functions.myfunctions:
# >> (LSL time synchronized)
# WARNING:libmushu.driver.labstreaminglayer:
# >>*****WAITING LSL MARKER STREAM: *****
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> Streams : [u'PyffMarkerStream', u'BrainVision RDA']
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> GREAT - Only 1 PyffMarkerStream stream!
# INFO:testclass:Channels From Amplifier Mushu: ['Fp1', 'Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'TP9', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'Fp2']
# INFO:testclass:***init_acquisition***ELAPSED TIME: 1.40315485001
# INFO:testclass:
# >> BCI METHODS INITIATED!
# INFO:testclass:CURRENT FILE PATH: None
# INFO:testclass:CURRENT FILE PATH: None
# WARNING:libmushu.driver.labstreaminglayer:
# >> *****WAITING EEG STREAM: ******
# WARNING:libmushu.driver.labstreaminglayer:
# >> Waiting LSL EEG stream...
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> Streams : [u'PyffMarkerStream', u'BrainVision RDA']
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> GREAT - Only 1 BrainVision RDA stream!
# WARNING:libmushu.driver.labstreaminglayer:
# >>*****WAITING LSL MARKER STREAM: *****
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> Streams : [u'PyffMarkerStream', u'BrainVision RDA']
# WARNING:phdproject.maincode.src.functions.myfunctions:
# >> GREAT - Only 1 PyffMarkerStream stream!
# INFO:libmushu.driver.labstreaminglayer:
# >> Opening streams.
# INFO:libmushu.driver.labstreaminglayer:
# >> START RECEIVING DATA...
# >> STREAM: BrainVision RDA ; PID 8312)
# INFO:testclass:***set_pyff_vars***
# INFO:testclass:***set_pyff_vars***ELAPSED TIME: 0.000147104263306
# INFO:testclass:start_time: 1588591388.07
# INFO:testclass:
# >> PyffMarkerStream : 0.59185040349s, marker_step: 1, local_clock: 85537.9612289, marker_number: 71
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:01
# >> Received Samples Duration: 1.05 s
# >> Loop Duration: 1.04663085938 s
# >> Loop Elapsed time: 0.0548150539398 s
# >> Samples received : 1050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 1.59079263601s, marker_step: 1, local_clock: 85538.9616141, marker_number: 72
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:02
# >> Received Samples Duration: 2.05 s
# >> Loop Duration: 2.04383683205 s
# >> Loop Elapsed time: 0.0507428646088 s
# >> Samples received : 2050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 2.59270338699s, marker_step: 1, local_clock: 85539.9623618, marker_number: 73
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:03
# >> Received Samples Duration: 3.05 s
# >> Loop Duration: 3.08508491516 s
# >> Loop Elapsed time: 0.0500791072845 s
# >> Samples received : 3050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 3.59346991397s, marker_step: 1, local_clock: 85540.9626532, marker_number: 74
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:04
# >> Received Samples Duration: 4.05 s
# >> Loop Duration: 4.06827092171 s
# >> Loop Elapsed time: 0.050183057785 s
# >> Samples received : 4050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 4.59309219799s, marker_step: 1, local_clock: 85541.9629527, marker_number: 75
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:05
# >> Received Samples Duration: 5.05 s
# >> Loop Duration: 5.06289696693 s
# >> Loop Elapsed time: 0.0530362129211 s
# >> Samples received : 5050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 5.59353353402s, marker_step: 1, local_clock: 85542.9632256, marker_number: 76
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:06
# >> Received Samples Duration: 6.05 s
# >> Loop Duration: 6.05355191231 s
# >> Loop Elapsed time: 0.0500540733337 s
# >> Samples received : 6050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 6.5944246835s, marker_step: 1, local_clock: 85543.9635131, marker_number: 77
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:07
# >> Received Samples Duration: 7.05 s
# >> Loop Duration: 7.07859182358 s
# >> Loop Elapsed time: 0.0502350330353 s
# >> Samples received : 7050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 7.59513924749s, marker_step: 1, local_clock: 85544.9642031, marker_number: 78
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:08
# >> Received Samples Duration: 8.05 s
# >> Loop Duration: 8.0722849369 s
# >> Loop Elapsed time: 0.0501301288605 s
# >> Samples received : 8050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 8.59570253349s, marker_step: 1, local_clock: 85545.9647467, marker_number: 79
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:09
# >> Received Samples Duration: 9.05 s
# >> Loop Duration: 9.04532885551 s
# >> Loop Elapsed time: 0.0539979934692 s
# >> Samples received : 9050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 9.59604219249s, marker_step: 1, local_clock: 85546.9651073, marker_number: 80
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:10
# >> Received Samples Duration: 10.05 s
# >> Loop Duration: 10.04565382 s
# >> Loop Elapsed time: 0.0512402057648 s
# >> Samples received : 10050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 10.596652868s, marker_step: 1, local_clock: 85547.9656144, marker_number: 81
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:11
# >> Received Samples Duration: 11.05 s
# >> Loop Duration: 11.0845417976 s
# >> Loop Elapsed time: 0.0509400367737 s
# >> Samples received : 11050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 11.596941379s, marker_step: 1, local_clock: 85548.9659142, marker_number: 82
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:12
# >> Received Samples Duration: 12.05 s
# >> Loop Duration: 12.0760409832 s
# >> Loop Elapsed time: 0.0509049892426 s
# >> Samples received : 12050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 12.5976058185s, marker_step: 1, local_clock: 85549.9665578, marker_number: 83
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:13
# >> Received Samples Duration: 13.05 s
# >> Loop Duration: 13.0609788895 s
# >> Loop Elapsed time: 0.0512399673462 s
# >> Samples received : 13050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 13.598397551s, marker_step: 1, local_clock: 85550.9673332, marker_number: 84
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:14
# >> Received Samples Duration: 14.05 s
# >> Loop Duration: 14.0395758152 s
# >> Loop Elapsed time: 0.0512268543243 s
# >> Samples received : 14050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 14.598394949s, marker_step: 1, local_clock: 85551.9684546, marker_number: 85
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:15
# >> Received Samples Duration: 15.05 s
# >> Loop Duration: 15.0879619122 s
# >> Loop Elapsed time: 0.0529170036316 s
# >> Samples received : 15050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 15.602067937s, marker_step: 1, local_clock: 85552.9708601, marker_number: 86
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:16
# >> Received Samples Duration: 16.05 s
# >> Loop Duration: 16.0834670067 s
# >> Loop Elapsed time: 0.0540950298309 s
# >> Samples received : 16050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 16.602349924s, marker_step: 1, local_clock: 85553.9711457, marker_number: 87
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:17
# >> Received Samples Duration: 17.05 s
# >> Loop Duration: 17.0679018497 s
# >> Loop Elapsed time: 0.0501050949097 s
# >> Samples received : 17050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 17.602509242s, marker_step: 1, local_clock: 85554.9715026, marker_number: 88
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:18
# >> Received Samples Duration: 18.05 s
# >> Loop Duration: 18.0640199184 s
# >> Loop Elapsed time: 0.0550191402435 s
# >> Samples received : 18050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 18.6030490935s, marker_step: 1, local_clock: 85555.9721736, marker_number: 89
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:19
# >> Received Samples Duration: 19.05 s
# >> Loop Duration: 19.0593218803 s
# >> Loop Elapsed time: 0.0509099960327 s
# >> Samples received : 19050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 19.6037993365s, marker_step: 1, local_clock: 85556.9724633, marker_number: 90
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:20
# >> Received Samples Duration: 20.05 s
# >> Loop Duration: 20.0566909313 s
# >> Loop Elapsed time: 0.0543630123138 s
# >> Samples received : 20050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 20.604547164s, marker_step: 1, local_clock: 85557.9731978, marker_number: 91
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:21
# >> Received Samples Duration: 21.05 s
# >> Loop Duration: 21.0579378605 s
# >> Loop Elapsed time: 0.0534110069275 s
# >> Samples received : 21050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 21.604884391s, marker_step: 1, local_clock: 85558.9734897, marker_number: 92
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:22
# >> Received Samples Duration: 22.05 s
# >> Loop Duration: 22.0569078922 s
# >> Loop Elapsed time: 0.0512230396271 s
# >> Samples received : 22050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 22.605215797s, marker_step: 1, local_clock: 85559.9738451, marker_number: 93
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:23
# >> Received Samples Duration: 23.05 s
# >> Loop Duration: 23.0589468479 s
# >> Loop Elapsed time: 0.0508599281311 s
# >> Samples received : 23050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 23.603310013s, marker_step: 1, local_clock: 85560.9747757, marker_number: 94
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:24
# >> Received Samples Duration: 24.05 s
# >> Loop Duration: 24.0599048138 s
# >> Loop Elapsed time: 0.0528419017792 s
# >> Samples received : 24050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 24.6071850105s, marker_step: 1, local_clock: 85561.975726, marker_number: 95
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:25
# >> Received Samples Duration: 25.05 s
# >> Loop Duration: 25.0606248379 s
# >> Loop Elapsed time: 0.0500619411469 s
# >> Samples received : 25050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 25.607910423s, marker_step: 1, local_clock: 85562.9764477, marker_number: 96
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:26
# >> Received Samples Duration: 26.05 s
# >> Loop Duration: 26.0551159382 s
# >> Loop Elapsed time: 0.0533540248871 s
# >> Samples received : 26050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 26.6083808175s, marker_step: 1, local_clock: 85563.9768408, marker_number: 97
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:27
# >> Received Samples Duration: 27.05 s
# >> Loop Duration: 27.0625679493 s
# >> Loop Elapsed time: 0.0515551567078 s
# >> Samples received : 27050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 27.6084281175s, marker_step: 1, local_clock: 85564.9773668, marker_number: 98
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:28
# >> Received Samples Duration: 28.05 s
# >> Loop Duration: 28.0885808468 s
# >> Loop Elapsed time: 0.0535840988159 s
# >> Samples received : 28050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 28.609942898s, marker_step: 1, local_clock: 85565.9783985, marker_number: 99
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:29
# >> Received Samples Duration: 29.05 s
# >> Loop Duration: 29.0683338642 s
# >> Loop Elapsed time: 0.0509150028229 s
# >> Samples received : 29050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 29.610251988s, marker_step: 1, local_clock: 85566.9787485, marker_number: 100
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:30
# >> Received Samples Duration: 30.05 s
# >> Loop Duration: 30.0702049732 s
# >> Loop Elapsed time: 0.0502569675446 s
# >> Samples received : 30050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 30.6107739335s, marker_step: 1, local_clock: 85567.979144, marker_number: 101
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:31
# >> Received Samples Duration: 31.05 s
# >> Loop Duration: 31.0601348877 s
# >> Loop Elapsed time: 0.0549340248108 s
# >> Samples received : 31050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 31.6112847085s, marker_step: 1, local_clock: 85568.9799089, marker_number: 102
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:32
# >> Received Samples Duration: 32.05 s
# >> Loop Duration: 32.0515317917 s
# >> Loop Elapsed time: 0.0529730319977 s
# >> Samples received : 32050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 32.6121785405s, marker_step: 1, local_clock: 85569.9804576, marker_number: 103
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:33
# >> Received Samples Duration: 33.05 s
# >> Loop Duration: 33.0487208366 s
# >> Loop Elapsed time: 0.0547499656677 s
# >> Samples received : 33050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 33.6125108285s, marker_step: 1, local_clock: 85570.9810321, marker_number: 104
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:34
# >> Received Samples Duration: 34.05 s
# >> Loop Duration: 34.0850229263 s
# >> Loop Elapsed time: 0.0547790527344 s
# >> Samples received : 34050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 34.6130973625s, marker_step: 1, local_clock: 85571.9813703, marker_number: 105
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:35
# >> Received Samples Duration: 35.05 s
# >> Loop Duration: 35.0769298077 s
# >> Loop Elapsed time: 0.0549650192261 s
# >> Samples received : 35050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 35.613411339s, marker_step: 1, local_clock: 85572.9816717, marker_number: 106
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:36
# >> Received Samples Duration: 36.05 s
# >> Loop Duration: 36.0698978901 s
# >> Loop Elapsed time: 0.0538790225983 s
# >> Samples received : 36050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 36.614258646s, marker_step: 1, local_clock: 85573.9824353, marker_number: 107
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:37
# >> Received Samples Duration: 37.05 s
# >> Loop Duration: 37.0749189854 s
# >> Loop Elapsed time: 0.0509760379791 s
# >> Samples received : 37050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 37.615005131s, marker_step: 1, local_clock: 85574.9831353, marker_number: 108
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:38
# >> Received Samples Duration: 38.05 s
# >> Loop Duration: 38.0628318787 s
# >> Loop Elapsed time: 0.0544021129608 s
# >> Samples received : 38050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 38.615777184s, marker_step: 1, local_clock: 85575.9839934, marker_number: 109
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:39
# >> Received Samples Duration: 39.05 s
# >> Loop Duration: 39.0676429272 s
# >> Loop Elapsed time: 0.0543711185455 s
# >> Samples received : 39050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 39.616303433s, marker_step: 1, local_clock: 85576.9844079, marker_number: 110
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:40
# >> Received Samples Duration: 40.05 s
# >> Loop Duration: 40.0734639168 s
# >> Loop Elapsed time: 0.0549919605255 s
# >> Samples received : 40050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 40.6166902155s, marker_step: 1, local_clock: 85577.9847697, marker_number: 111
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:41
# >> Received Samples Duration: 41.05 s
# >> Loop Duration: 41.0569508076 s
# >> Loop Elapsed time: 0.0501458644867 s
# >> Samples received : 41050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 41.6173327365s, marker_step: 1, local_clock: 85578.9854024, marker_number: 112
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:42
# >> Received Samples Duration: 42.05 s
# >> Loop Duration: 42.0590348244 s
# >> Loop Elapsed time: 0.0543100833893 s
# >> Samples received : 42050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 42.6180428s, marker_step: 1, local_clock: 85579.986542, marker_number: 113
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:43
# >> Received Samples Duration: 43.05 s
# >> Loop Duration: 43.0594129562 s
# >> Loop Elapsed time: 0.051069021225 s
# >> Samples received : 43050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 43.6188519195s, marker_step: 1, local_clock: 85580.9868416, marker_number: 114
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:44
# >> Received Samples Duration: 44.05 s
# >> Loop Duration: 44.0579898357 s
# >> Loop Elapsed time: 0.0522708892822 s
# >> Samples received : 44050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 44.6192030855s, marker_step: 1, local_clock: 85581.9871456, marker_number: 115
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:45
# >> Received Samples Duration: 45.05 s
# >> Loop Duration: 45.0459959507 s
# >> Loop Elapsed time: 0.0512840747833 s
# >> Samples received : 45050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 45.665073224s, marker_step: 1, local_clock: 85582.9874317, marker_number: 116
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:46
# >> Received Samples Duration: 46.05 s
# >> Loop Duration: 46.0380949974 s
# >> Loop Elapsed time: 0.0503778457642 s
# >> Samples received : 46050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 46.6664318085s, marker_step: 1, local_clock: 85583.988236, marker_number: 117
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:47
# >> Received Samples Duration: 47.05 s
# >> Loop Duration: 47.0246648788 s
# >> Loop Elapsed time: 0.0510540008545 s
# >> Samples received : 47050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 47.666565269s, marker_step: 1, local_clock: 85584.9888857, marker_number: 118
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:48
# >> Received Samples Duration: 48.05 s
# >> Loop Duration: 48.0089149475 s
# >> Loop Elapsed time: 0.0510890483856 s
# >> Samples received : 48050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 48.6676810225s, marker_step: 1, local_clock: 85585.9894845, marker_number: 119
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:49
# >> Received Samples Duration: 49.1 s
# >> Loop Duration: 49.0435349941 s
# >> Loop Elapsed time: 0.0523099899292 s
# >> Samples received : 49100
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 49.667575747s, marker_step: 1, local_clock: 85586.9897758, marker_number: 120
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:50
# >> Received Samples Duration: 50.05 s
# >> Loop Duration: 49.996172905 s
# >> Loop Elapsed time: 0.0543019771576 s
# >> Samples received : 50050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 50.668446582s, marker_step: 1, local_clock: 85587.9901647, marker_number: 121
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:51
# >> Received Samples Duration: 51.05 s
# >> Loop Duration: 51.0311849117 s
# >> Loop Elapsed time: 0.0526010990143 s
# >> Samples received : 51050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 51.6682862915s, marker_step: 1, local_clock: 85588.9905033, marker_number: 122
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:52
# >> Received Samples Duration: 52.05 s
# >> Loop Duration: 52.018545866 s
# >> Loop Elapsed time: 0.0545480251312 s
# >> Samples received : 52050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 52.6690982415s, marker_step: 1, local_clock: 85589.9908093, marker_number: 123
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:53
# >> Received Samples Duration: 53.05 s
# >> Loop Duration: 53.0176038742 s
# >> Loop Elapsed time: 0.0508711338043 s
# >> Samples received : 53050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 53.6697148165s, marker_step: 1, local_clock: 85590.9913149, marker_number: 124
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:54
# >> Received Samples Duration: 54.05 s
# >> Loop Duration: 54.0208787918 s
# >> Loop Elapsed time: 0.0520288944244 s
# >> Samples received : 54050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 54.670380833s, marker_step: 1, local_clock: 85591.9920165, marker_number: 125
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:55
# >> Received Samples Duration: 55.05 s
# >> Loop Duration: 55.0025589466 s
# >> Loop Elapsed time: 0.0540251731873 s
# >> Samples received : 55050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 55.6711176255s, marker_step: 1, local_clock: 85592.9926697, marker_number: 126
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:56
# >> Received Samples Duration: 56.05 s
# >> Loop Duration: 55.9985539913 s
# >> Loop Elapsed time: 0.0564448833466 s
# >> Samples received : 56050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 56.671808842s, marker_step: 1, local_clock: 85593.993329, marker_number: 127
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:57
# >> Received Samples Duration: 57.05 s
# >> Loop Duration: 57.0434288979 s
# >> Loop Elapsed time: 0.0538151264191 s
# >> Samples received : 57050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 57.6718321555s, marker_step: 1, local_clock: 85594.9939257, marker_number: 128
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:58
# >> Received Samples Duration: 58.05 s
# >> Loop Duration: 57.9946467876 s
# >> Loop Elapsed time: 0.0532038211823 s
# >> Samples received : 58050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 58.673798308s, marker_step: 1, local_clock: 85595.9961542, marker_number: 129
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:00:59
# >> Received Samples Duration: 59.1 s
# >> Loop Duration: 59.049394846 s
# >> Loop Elapsed time: 0.0549340248108 s
# >> Samples received : 59100
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 59.671062742s, marker_step: 1, local_clock: 85596.9999675, marker_number: 130
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:00
# >> Received Samples Duration: 60.05 s
# >> Loop Duration: 59.9953348637 s
# >> Loop Elapsed time: 0.0510969161987 s
# >> Samples received : 60050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 60.6819530595s, marker_step: 1, local_clock: 85598.0033971, marker_number: 131
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:01
# >> Received Samples Duration: 61.05 s
# >> Loop Duration: 60.9981110096 s
# >> Loop Elapsed time: 0.0544338226318 s
# >> Samples received : 61050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 61.681898665s, marker_step: 1, local_clock: 85599.0037651, marker_number: 132
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:02
# >> Received Samples Duration: 62.05 s
# >> Loop Duration: 62.0092349052 s
# >> Loop Elapsed time: 0.0518929958344 s
# >> Samples received : 62050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 62.684013052s, marker_step: 1, local_clock: 85600.0053915, marker_number: 133
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:03
# >> Received Samples Duration: 63.05 s
# >> Loop Duration: 63.0111129284 s
# >> Loop Elapsed time: 0.0502920150757 s
# >> Samples received : 63050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 63.684376393s, marker_step: 1, local_clock: 85601.0057044, marker_number: 134
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:04
# >> Received Samples Duration: 64.05 s
# >> Loop Duration: 64.0127949715 s
# >> Loop Elapsed time: 0.0519912242889 s
# >> Samples received : 64050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 64.684207845s, marker_step: 1, local_clock: 85602.0060112, marker_number: 135
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:05
# >> Received Samples Duration: 65.05 s
# >> Loop Duration: 65.0142459869 s
# >> Loop Elapsed time: 0.052531003952 s
# >> Samples received : 65050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 65.684909664s, marker_step: 1, local_clock: 85603.0066819, marker_number: 136
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:06
# >> Received Samples Duration: 66.05 s
# >> Loop Duration: 66.0334010124 s
# >> Loop Elapsed time: 0.0550739765167 s
# >> Samples received : 66050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 66.686296354s, marker_step: 1, local_clock: 85604.0075457, marker_number: 137
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:07
# >> Received Samples Duration: 67.05 s
# >> Loop Duration: 67.0329358578 s
# >> Loop Elapsed time: 0.0544550418854 s
# >> Samples received : 67050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 67.6867250325s, marker_step: 1, local_clock: 85605.007887, marker_number: 138
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:08
# >> Received Samples Duration: 68.05 s
# >> Loop Duration: 68.0263829231 s
# >> Loop Elapsed time: 0.0538830757141 s
# >> Samples received : 68050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 68.686982409s, marker_step: 1, local_clock: 85606.0082264, marker_number: 139
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:09
# >> Received Samples Duration: 69.05 s
# >> Loop Duration: 69.0177869797 s
# >> Loop Elapsed time: 0.0536758899689 s
# >> Samples received : 69050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 69.6878908605s, marker_step: 1, local_clock: 85607.0090511, marker_number: 140
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:10
# >> Received Samples Duration: 70.05 s
# >> Loop Duration: 70.0213868618 s
# >> Loop Elapsed time: 0.0530979633331 s
# >> Samples received : 70050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 70.6883946515s, marker_step: 1, local_clock: 85608.009483, marker_number: 141
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:11
# >> Received Samples Duration: 71.05 s
# >> Loop Duration: 71.0301709175 s
# >> Loop Elapsed time: 0.0500359535217 s
# >> Samples received : 71050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 71.688312928s, marker_step: 1, local_clock: 85609.0101331, marker_number: 142
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:12
# >> Received Samples Duration: 72.05 s
# >> Loop Duration: 72.0273258686 s
# >> Loop Elapsed time: 0.0512731075287 s
# >> Samples received : 72050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 72.689312221s, marker_step: 1, local_clock: 85610.0108731, marker_number: 143
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:13
# >> Received Samples Duration: 73.05 s
# >> Loop Duration: 73.0254569054 s
# >> Loop Elapsed time: 0.0512850284576 s
# >> Samples received : 73050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 73.689475417s, marker_step: 1, local_clock: 85611.0111994, marker_number: 144
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:14
# >> Received Samples Duration: 74.05 s
# >> Loop Duration: 74.0230789185 s
# >> Loop Elapsed time: 0.0505411624908 s
# >> Samples received : 74050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 74.6900917405s, marker_step: 1, local_clock: 85612.0116072, marker_number: 145
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:15
# >> Received Samples Duration: 75.05 s
# >> Loop Duration: 75.0176799297 s
# >> Loop Elapsed time: 0.0522010326385 s
# >> Samples received : 75050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 75.693912298s, marker_step: 1, local_clock: 85613.0152216, marker_number: 146
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:16
# >> Received Samples Duration: 76.05 s
# >> Loop Duration: 76.012513876 s
# >> Loop Elapsed time: 0.0550150871277 s
# >> Samples received : 76050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 76.6948086325s, marker_step: 1, local_clock: 85614.0162678, marker_number: 147
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:17
# >> Received Samples Duration: 77.05 s
# >> Loop Duration: 77.0116708279 s
# >> Loop Elapsed time: 0.0506129264832 s
# >> Samples received : 77050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 77.6961513195s, marker_step: 1, local_clock: 85615.0170996, marker_number: 148
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:18
# >> Received Samples Duration: 78.05 s
# >> Loop Duration: 78.0145759583 s
# >> Loop Elapsed time: 0.0522301197052 s
# >> Samples received : 78050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 78.696887441s, marker_step: 1, local_clock: 85616.0177576, marker_number: 149
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:19
# >> Received Samples Duration: 79.05 s
# >> Loop Duration: 78.99629879 s
# >> Loop Elapsed time: 0.0522599220276 s
# >> Samples received : 79050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 79.6973085835s, marker_step: 1, local_clock: 85617.0181267, marker_number: 150
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:20
# >> Received Samples Duration: 80.05 s
# >> Loop Duration: 80.0268409252 s
# >> Loop Elapsed time: 0.0503101348877 s
# >> Samples received : 80050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 80.6979381665s, marker_step: 1, local_clock: 85618.0188113, marker_number: 151
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:21
# >> Received Samples Duration: 81.05 s
# >> Loop Duration: 81.0178239346 s
# >> Loop Elapsed time: 0.0541470050812 s
# >> Samples received : 81050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 81.698347521s, marker_step: 1, local_clock: 85619.01921, marker_number: 152
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:22
# >> Received Samples Duration: 82.05 s
# >> Loop Duration: 82.0059549809 s
# >> Loop Elapsed time: 0.0505449771881 s
# >> Samples received : 82050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 82.6989073005s, marker_step: 1, local_clock: 85620.0196637, marker_number: 153
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:23
# >> Received Samples Duration: 83.05 s
# >> Loop Duration: 83.0033888817 s
# >> Loop Elapsed time: 0.0509369373322 s
# >> Samples received : 83050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 83.699737688s, marker_step: 1, local_clock: 85621.0205238, marker_number: 154
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:24
# >> Received Samples Duration: 84.05 s
# >> Loop Duration: 83.999494791 s
# >> Loop Elapsed time: 0.0547368526459 s
# >> Samples received : 84050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 84.7004490075s, marker_step: 1, local_clock: 85622.0211287, marker_number: 155
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:25
# >> Received Samples Duration: 85.05 s
# >> Loop Duration: 84.9948318005 s
# >> Loop Elapsed time: 0.0502989292145 s
# >> Samples received : 85050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 85.701465003s, marker_step: 1, local_clock: 85623.0227826, marker_number: 156
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:26
# >> Received Samples Duration: 86.05 s
# >> Loop Duration: 86.0363190174 s
# >> Loop Elapsed time: 0.0524339675903 s
# >> Samples received : 86050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 86.7024335695s, marker_step: 1, local_clock: 85624.0247817, marker_number: 157
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:27
# >> Received Samples Duration: 87.05 s
# >> Loop Duration: 87.0258059502 s
# >> Loop Elapsed time: 0.0510010719299 s
# >> Samples received : 87050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 87.7093728715s, marker_step: 1, local_clock: 85625.0429159, marker_number: 158
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:28
# >> Received Samples Duration: 88.05 s
# >> Loop Duration: 88.0361390114 s
# >> Loop Elapsed time: 0.0547759532928 s
# >> Samples received : 88050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 88.7220253015s, marker_step: 1, local_clock: 85626.0437889, marker_number: 159
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:29
# >> Received Samples Duration: 89.05 s
# >> Loop Duration: 89.0372309685 s
# >> Loop Elapsed time: 0.0502371788025 s
# >> Samples received : 89050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 89.723384856s, marker_step: 1, local_clock: 85627.0444426, marker_number: 160
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:30
# >> Received Samples Duration: 90.1 s
# >> Loop Duration: 90.0444610119 s
# >> Loop Elapsed time: 0.0544588565826 s
# >> Samples received : 90100
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 90.7248286225s, marker_step: 1, local_clock: 85628.0453449, marker_number: 161
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:31
# >> Received Samples Duration: 91.05 s
# >> Loop Duration: 91.0026760101 s
# >> Loop Elapsed time: 0.0544698238373 s
# >> Samples received : 91050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 91.724580348s, marker_step: 1, local_clock: 85629.0456412, marker_number: 162
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:32
# >> Received Samples Duration: 92.05 s
# >> Loop Duration: 92.004858017 s
# >> Loop Elapsed time: 0.0518419742584 s
# >> Samples received : 92050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 92.7250202385s, marker_step: 1, local_clock: 85630.0459749, marker_number: 163
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:33
# >> Received Samples Duration: 93.05 s
# >> Loop Duration: 93.0106458664 s
# >> Loop Elapsed time: 0.0549249649048 s
# >> Samples received : 93050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 93.7266978115s, marker_step: 1, local_clock: 85631.0477095, marker_number: 164
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:34
# >> Received Samples Duration: 94.05 s
# >> Loop Duration: 94.0070300102 s
# >> Loop Elapsed time: 0.0526938438416 s
# >> Samples received : 94050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 94.7278599035s, marker_step: 1, local_clock: 85632.0482271, marker_number: 165
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:35
# >> Received Samples Duration: 95.05 s
# >> Loop Duration: 95.0087850094 s
# >> Loop Elapsed time: 0.0544619560242 s
# >> Samples received : 95050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 95.7284757045s, marker_step: 1, local_clock: 85633.0488432, marker_number: 166
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:36
# >> Received Samples Duration: 96.05 s
# >> Loop Duration: 96.0450379848 s
# >> Loop Elapsed time: 0.0543329715729 s
# >> Samples received : 96050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 96.7288579105s, marker_step: 1, local_clock: 85634.0492202, marker_number: 167
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:37
# >> Received Samples Duration: 97.05 s
# >> Loop Duration: 97.0217359066 s
# >> Loop Elapsed time: 0.0500440597534 s
# >> Samples received : 97050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 97.7295557795s, marker_step: 1, local_clock: 85635.0498717, marker_number: 168
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:38
# >> Received Samples Duration: 98.05 s
# >> Loop Duration: 98.0052478313 s
# >> Loop Elapsed time: 0.0502939224243 s
# >> Samples received : 98050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 98.72996024s, marker_step: 1, local_clock: 85636.0503729, marker_number: 169
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:39
# >> Received Samples Duration: 99.05 s
# >> Loop Duration: 99.0186789036 s
# >> Loop Elapsed time: 0.0529451370239 s
# >> Samples received : 99050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 99.7312691945s, marker_step: 1, local_clock: 85637.0516591, marker_number: 170
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:40
# >> Received Samples Duration: 100.05 s
# >> Loop Duration: 100.010863781 s
# >> Loop Elapsed time: 0.0546839237213 s
# >> Samples received : 100050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 100.73178732s, marker_step: 1, local_clock: 85638.0519585, marker_number: 171
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:41
# >> Received Samples Duration: 101.05 s
# >> Loop Duration: 101.012931824 s
# >> Loop Elapsed time: 0.0497879981995 s
# >> Samples received : 101050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 101.73160029s, marker_step: 1, local_clock: 85639.0523545, marker_number: 172
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:42
# >> Received Samples Duration: 102.05 s
# >> Loop Duration: 102.012490988 s
# >> Loop Elapsed time: 0.051903963089 s
# >> Samples received : 102050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 102.729534217s, marker_step: 1, local_clock: 85640.0530665, marker_number: 173
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:43
# >> Received Samples Duration: 103.05 s
# >> Loop Duration: 103.037899017 s
# >> Loop Elapsed time: 0.052591085434 s
# >> Samples received : 103050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 103.732349638s, marker_step: 1, local_clock: 85641.0537663, marker_number: 174
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:44
# >> Received Samples Duration: 104.05 s
# >> Loop Duration: 104.03834796 s
# >> Loop Elapsed time: 0.0548551082611 s
# >> Samples received : 104050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 104.733988497s, marker_step: 1, local_clock: 85642.0542985, marker_number: 175
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:45
# >> Received Samples Duration: 105.05 s
# >> Loop Duration: 105.003819942 s
# >> Loop Elapsed time: 0.0544099807739 s
# >> Samples received : 105050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 105.735198167s, marker_step: 1, local_clock: 85643.0552312, marker_number: 176
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:46
# >> Received Samples Duration: 106.05 s
# >> Loop Duration: 106.014832973 s
# >> Loop Elapsed time: 0.0541498661041 s
# >> Samples received : 106050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 106.734856087s, marker_step: 1, local_clock: 85644.055921, marker_number: 177
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:47
# >> Received Samples Duration: 107.05 s
# >> Loop Duration: 107.015739918 s
# >> Loop Elapsed time: 0.054591178894 s
# >> Samples received : 107050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 107.734202553s, marker_step: 1, local_clock: 85645.0629643, marker_number: 178
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:48
# >> Received Samples Duration: 108.05 s
# >> Loop Duration: 108.024400949 s
# >> Loop Elapsed time: 0.0544440746307 s
# >> Samples received : 108050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 108.743366933s, marker_step: 1, local_clock: 85646.063899, marker_number: 179
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:49
# >> Received Samples Duration: 109.05 s
# >> Loop Duration: 109.023474932 s
# >> Loop Elapsed time: 0.0517508983612 s
# >> Samples received : 109050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 109.743329101s, marker_step: 1, local_clock: 85647.0646895, marker_number: 180
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:50
# >> Received Samples Duration: 110.05 s
# >> Loop Duration: 110.025797844 s
# >> Loop Elapsed time: 0.0503950119019 s
# >> Samples received : 110050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 110.745597875s, marker_step: 1, local_clock: 85648.0654711, marker_number: 181
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:51
# >> Received Samples Duration: 111.05 s
# >> Loop Duration: 111.03140378 s
# >> Loop Elapsed time: 0.0506188869476 s
# >> Samples received : 111050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 111.745888771s, marker_step: 1, local_clock: 85649.0657488, marker_number: 182
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:52
# >> Received Samples Duration: 112.05 s
# >> Loop Duration: 112.044922829 s
# >> Loop Elapsed time: 0.0535109043121 s
# >> Samples received : 112050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 112.745702937s, marker_step: 1, local_clock: 85650.0660563, marker_number: 183
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:53
# >> Received Samples Duration: 113.05 s
# >> Loop Duration: 112.996043921 s
# >> Loop Elapsed time: 0.0531821250916 s
# >> Samples received : 113050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 113.747104144s, marker_step: 1, local_clock: 85651.0668832, marker_number: 184
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:54
# >> Received Samples Duration: 114.05 s
# >> Loop Duration: 113.998116016 s
# >> Loop Elapsed time: 0.0503869056702 s
# >> Samples received : 114050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 114.747364983s, marker_step: 1, local_clock: 85652.0671737, marker_number: 185
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:55
# >> Received Samples Duration: 115.05 s
# >> Loop Duration: 115.040248871 s
# >> Loop Elapsed time: 0.0517721176147 s
# >> Samples received : 115050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 115.747703538s, marker_step: 1, local_clock: 85653.0674868, marker_number: 186
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:56
# >> Received Samples Duration: 116.05 s
# >> Loop Duration: 116.044094801 s
# >> Loop Elapsed time: 0.0537800788879 s
# >> Samples received : 116050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 116.747953906s, marker_step: 1, local_clock: 85654.0677892, marker_number: 187
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:57
# >> Received Samples Duration: 117.05 s
# >> Loop Duration: 117.033199787 s
# >> Loop Elapsed time: 0.0525119304657 s
# >> Samples received : 117050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 117.748833421s, marker_step: 1, local_clock: 85655.0685139, marker_number: 188
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:58
# >> Received Samples Duration: 118.05 s
# >> Loop Duration: 118.038235903 s
# >> Loop Elapsed time: 0.0518419742584 s
# >> Samples received : 118050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 118.748126196s, marker_step: 1, local_clock: 85656.0690074, marker_number: 189
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:01:59
# >> Received Samples Duration: 119.05 s
# >> Loop Duration: 118.995271921 s
# >> Loop Elapsed time: 0.054309129715 s
# >> Samples received : 119050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 119.749822949s, marker_step: 1, local_clock: 85657.0694543, marker_number: 190
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:00
# >> Received Samples Duration: 120.1 s
# >> Loop Duration: 120.041557789 s
# >> Loop Elapsed time: 0.0501208305359 s
# >> Samples received : 120100
# >> get_data chunk average : 100
# ...
# INFO:testclass:
# >> PyffMarkerStream : 150.792977704s, marker_step: 1, local_clock: 85688.1122985, marker_number: 221
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:31
# >> Received Samples Duration: 151.05 s
# >> Loop Duration: 151.008486986 s
# >> Loop Elapsed time: 0.0502579212189 s
# >> Samples received : 151050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 151.794508475s, marker_step: 1, local_clock: 85689.1131469, marker_number: 222
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:32
# >> Received Samples Duration: 152.05 s
# >> Loop Duration: 151.991483927 s
# >> Loop Elapsed time: 0.0501019954681 s
# >> Samples received : 152050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 152.794778346s, marker_step: 1, local_clock: 85690.1134476, marker_number: 223
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:33
# >> Received Samples Duration: 153.1 s
# >> Loop Duration: 153.042953014 s
# >> Loop Elapsed time: 0.0513389110565 s
# >> Samples received : 153100
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 153.795575568s, marker_step: 1, local_clock: 85691.1147291, marker_number: 224
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:34
# >> Received Samples Duration: 154.05 s
# >> Loop Duration: 154.043802977 s
# >> Loop Elapsed time: 0.0540289878845 s
# >> Samples received : 154050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 154.796536798s, marker_step: 1, local_clock: 85692.1150828, marker_number: 225
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:35
# >> Received Samples Duration: 155.05 s
# >> Loop Duration: 155.040499926 s
# >> Loop Elapsed time: 0.0500719547272 s
# >> Samples received : 155050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 155.797229701s, marker_step: 1, local_clock: 85693.1157603, marker_number: 226
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:36
# >> Received Samples Duration: 156.05 s
# >> Loop Duration: 156.039550781 s
# >> Loop Elapsed time: 0.0547490119934 s
# >> Samples received : 156050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 156.797564244s, marker_step: 1, local_clock: 85694.1160505, marker_number: 227
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:37
# >> Received Samples Duration: 157.05 s
# >> Loop Duration: 157.043646812 s
# >> Loop Elapsed time: 0.0521619319916 s
# >> Samples received : 157050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 157.798127544s, marker_step: 1, local_clock: 85695.1167603, marker_number: 228
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:38
# >> Received Samples Duration: 158.05 s
# >> Loop Duration: 157.998016834 s
# >> Loop Elapsed time: 0.05317902565 s
# >> Samples received : 158050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 158.797675665s, marker_step: 1, local_clock: 85696.1351184, marker_number: 229
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:39
# >> Received Samples Duration: 159.05 s
# >> Loop Duration: 159.021346807 s
# >> Loop Elapsed time: 0.0544679164886 s
# >> Samples received : 159050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 159.816995867s, marker_step: 1, local_clock: 85697.1362813, marker_number: 230
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:40
# >> Received Samples Duration: 160.05 s
# >> Loop Duration: 160.034102917 s
# >> Loop Elapsed time: 0.0540521144867 s
# >> Samples received : 160050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 160.819925496s, marker_step: 1, local_clock: 85698.1390664, marker_number: 231
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:41
# >> Received Samples Duration: 161.05 s
# >> Loop Duration: 161.04200983 s
# >> Loop Elapsed time: 0.0545990467072 s
# >> Samples received : 161050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 161.822928439s, marker_step: 1, local_clock: 85699.1413204, marker_number: 232
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:42
# >> Received Samples Duration: 162.082 s
# >> Loop Duration: 162.044114828 s
# >> Loop Elapsed time: 0.0532610416412 s
# >> Samples received : 162082
# >> get_data chunk average : 82
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 162.823030235s, marker_step: 1, local_clock: 85700.1420683, marker_number: 233
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:43
# >> Received Samples Duration: 163.05 s
# >> Loop Duration: 163.037186861 s
# >> Loop Elapsed time: 0.0521991252899 s
# >> Samples received : 163050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 163.824923737s, marker_step: 1, local_clock: 85701.1432452, marker_number: 234
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:44
# >> Received Samples Duration: 164.05 s
# >> Loop Duration: 164.039044857 s
# >> Loop Elapsed time: 0.0546391010284 s
# >> Samples received : 164050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 164.825600851s, marker_step: 1, local_clock: 85702.1438726, marker_number: 235
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:45
# >> Received Samples Duration: 165.05 s
# >> Loop Duration: 165.034895897 s
# >> Loop Elapsed time: 0.0508151054382 s
# >> Samples received : 165050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 165.825436363s, marker_step: 1, local_clock: 85703.1442412, marker_number: 236
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:46
# >> Received Samples Duration: 166.05 s
# >> Loop Duration: 166.038021803 s
# >> Loop Elapsed time: 0.0548839569092 s
# >> Samples received : 166050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 166.826693751s, marker_step: 1, local_clock: 85704.1449914, marker_number: 237
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:47
# >> Received Samples Duration: 167.05 s
# >> Loop Duration: 167.032445908 s
# >> Loop Elapsed time: 0.0502541065216 s
# >> Samples received : 167050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 167.827106503s, marker_step: 1, local_clock: 85705.145295, marker_number: 238
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:48
# >> Received Samples Duration: 168.05 s
# >> Loop Duration: 168.037376881 s
# >> Loop Elapsed time: 0.050096988678 s
# >> Samples received : 168050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 168.827442718s, marker_step: 1, local_clock: 85706.1455917, marker_number: 239
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:49
# >> Received Samples Duration: 169.05 s
# >> Loop Duration: 169.035730839 s
# >> Loop Elapsed time: 0.0522379875183 s
# >> Samples received : 169050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 169.827776807s, marker_step: 1, local_clock: 85707.1458883, marker_number: 240
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:50
# >> Received Samples Duration: 170.05 s
# >> Loop Duration: 170.035626888 s
# >> Loop Elapsed time: 0.0507400035858 s
# >> Samples received : 170050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 170.828093873s, marker_step: 1, local_clock: 85708.1462269, marker_number: 241
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:51
# >> Received Samples Duration: 171.05 s
# >> Loop Duration: 171.035168886 s
# >> Loop Elapsed time: 0.0534751415253 s
# >> Samples received : 171050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 171.829104194s, marker_step: 1, local_clock: 85709.1471461, marker_number: 242
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:52
# >> Received Samples Duration: 172.05 s
# >> Loop Duration: 172.029195786 s
# >> Loop Elapsed time: 0.0541059970856 s
# >> Samples received : 172050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 172.829861692s, marker_step: 1, local_clock: 85710.1478762, marker_number: 243
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:53
# >> Received Samples Duration: 173.05 s
# >> Loop Duration: 173.029238939 s
# >> Loop Elapsed time: 0.0547151565552 s
# >> Samples received : 173050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 173.830693112s, marker_step: 1, local_clock: 85711.1489916, marker_number: 244
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:54
# >> Received Samples Duration: 174.05 s
# >> Loop Duration: 174.010703802 s
# >> Loop Elapsed time: 0.0501239299774 s
# >> Samples received : 174050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 174.831630951s, marker_step: 1, local_clock: 85712.1496387, marker_number: 245
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:55
# >> Received Samples Duration: 175.05 s
# >> Loop Duration: 174.995398998 s
# >> Loop Elapsed time: 0.0501840114594 s
# >> Samples received : 175050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 175.832133567s, marker_step: 1, local_clock: 85713.1500684, marker_number: 246
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:56
# >> Received Samples Duration: 176.1 s
# >> Loop Duration: 176.048589945 s
# >> Loop Elapsed time: 0.0532410144806 s
# >> Samples received : 176100
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 176.832546991s, marker_step: 1, local_clock: 85714.1504612, marker_number: 247
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:57
# >> Received Samples Duration: 177.05 s
# >> Loop Duration: 177.036037922 s
# >> Loop Elapsed time: 0.0534119606018 s
# >> Samples received : 177050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 177.832484586s, marker_step: 1, local_clock: 85715.1510401, marker_number: 248
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:58
# >> Received Samples Duration: 178.05 s
# >> Loop Duration: 178.036864996 s
# >> Loop Elapsed time: 0.0502738952637 s
# >> Samples received : 178050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 178.833585917s, marker_step: 1, local_clock: 85716.1514217, marker_number: 249
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:02:59
# >> Received Samples Duration: 179.05 s
# >> Loop Duration: 179.029912949 s
# >> Loop Elapsed time: 0.0548100471497 s
# >> Samples received : 179050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 179.833622117s, marker_step: 1, local_clock: 85717.1517119, marker_number: 250
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:00
# >> Received Samples Duration: 180.05 s
# >> Loop Duration: 180.033677816 s
# >> Loop Elapsed time: 0.0524079799652 s
# >> Samples received : 180050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 180.834406247s, marker_step: 1, local_clock: 85718.1521587, marker_number: 251
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:01
# >> Received Samples Duration: 181.05 s
# >> Loop Duration: 181.016357899 s
# >> Loop Elapsed time: 0.0508179664612 s
# >> Samples received : 181050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 181.835061589s, marker_step: 1, local_clock: 85719.1527915, marker_number: 252
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:02
# >> Received Samples Duration: 182.05 s
# >> Loop Duration: 182.006367922 s
# >> Loop Elapsed time: 0.0536870956421 s
# >> Samples received : 182050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 182.835342042s, marker_step: 1, local_clock: 85720.1530983, marker_number: 253
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:03
# >> Received Samples Duration: 183.05 s
# >> Loop Duration: 183.002328873 s
# >> Loop Elapsed time: 0.0544531345367 s
# >> Samples received : 183050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 183.835523656s, marker_step: 1, local_clock: 85721.1534118, marker_number: 254
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:04
# >> Received Samples Duration: 184.05 s
# >> Loop Duration: 183.997963905 s
# >> Loop Elapsed time: 0.0544109344482 s
# >> Samples received : 184050
# >> get_data chunk average : 100
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 184.72262364s, marker_step: 1, local_clock: 85722.2006923, marker_number: 255
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:05
# >> Received Samples Duration: 185.05 s
# >> Loop Duration: 185.015074968 s
# >> Loop Elapsed time: 0.0539190769196 s
# >> Samples received : 185050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 185.886781678s, marker_step: 1, local_clock: 85723.2047638, marker_number: 256
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:06
# >> Received Samples Duration: 186.05 s
# >> Loop Duration: 186.003163815 s
# >> Loop Elapsed time: 0.0544021129608 s
# >> Samples received : 186050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 186.886835564s, marker_step: 1, local_clock: 85724.2051564, marker_number: 257
# INFO:testclass:
# >> BrainVision RDA 8312 DATETIME: 0:03:07
# >> Received Samples Duration: 187.05 s
# >> Loop Duration: 187.000361919 s
# >> Loop Elapsed time: 0.0528509616852 s
# >> Samples received : 187050
# >> get_data chunk average : 50
# >> Sample Rate: 1000.0
# INFO:testclass:
# >> PyffMarkerStream : 187.88705393s, marker_step: 1, local_clock: 85725.2058265, marker_number: 258
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d45f8a140c9b> in <module>()
#      11 #start experiment
#      12 test.RUNTRIAL_NR = 1 #1st trial
# ---> 13 test.on_play(markernumerate=test.RUNTRIAL_NR)
#      14 test.RUNTRIAL_NR = test.RUNTRIAL_NR+1 #2nd trial
#      15 test.on_play(markernumerate=test.RUNTRIAL_NR)
#
# <ipython-input-7-67671a189dc3> in on_play(self, markernumerate)
#      29         #START loop of data
#      30         self.start_time = time.time() #start time
# ---> 31         self.on_loop()
#      32         self.end_time = time.time()  #end time
#      33         self.elapsed_time =self.end_time - self.start_time
#
# /Users/nm.costa/Google_Drive/projects/phd/research/00_DataAnalysisTools_WS/python_workspace_NC/phdproject_master/phdproject/maincode/src/initbciclass.pyc in on_loop(self, restart, method, serialize)
#     546             #play loop
#     547             #*******LOOP TYPE****
# --> 548             if method=="simple": self.simple_loop()
#     549             if method=="closed_loop": self.closed_loop()
#     550             #***************
#
# /Users/nm.costa/Google_Drive/projects/phd/research/00_DataAnalysisTools_WS/python_workspace_NC/phdproject_master/phdproject/maincode/src/initbciclass.pyc in simple_loop(self, play_presentation)
#     621
#     622             #SLEEP
# --> 623             timer.sleep_atleast(server_buffer_time) #sleep at least the time that the chunk in the server needs to buffer
#     624
#     625             #LOG INFO
#
# /Users/nm.costa/Google_Drive/projects/phd/research/00_DataAnalysisTools_WS/python_workspace_NC/phdproject_master/phdproject/maincode/src/functions/myfunctions.pyc in sleep_atleast(self, sec)
#     838         timer_sec = self.sec()
#     839         if timer_sec < sec:
# --> 840             time.sleep(sec - timer_sec)
#     841             if self.autoreset: self.reset()
#     842
#
# KeyboardInterrupt:
